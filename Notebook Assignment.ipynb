# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
df = pd.read_csv('Data/medical data')
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %% [markdown]
# # VitD_levels

# %%
#get values
col='VitD_levels'
mean = df[col].mean()
median = df[col].median()
std = df[col].std()
plus_one_std = mean + std
minus_one_std = mean - std

# %% [markdown]
# ## Graph

# %%
fig,ax=plt.subplots(figsize=(10,6))
sns.histplot(x=df[col], kde=True, stat='density')
ax.axvline(mean, color='red', label = f'Mean={mean:,.2f}')
ax.axvline(median, color='green',label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color='k',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color='k', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(minus_one_std, plus_one_std, alpha=.6, color='yellow',zorder=0)
ax.set_title(f'{col} Distribution')
ax.legend();

# %%
from scipy import stats
kurt = stats.kurtosis(df[col], fisher = False)
kurt
# Out:
# 3.013147515833447

# %% [markdown]
# ## Questions

# %% [markdown]
# - Is it Discrete or Continuous?
#  - Continuous
# - Does it have a skew? If so, which direction (+/-)
#  - No
# - What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#  - kurt result around 3 so "mesokurtic"

# %% [markdown]
# # Doc_visits

# %%
#get values
col='Doc_visits'
mean = df[col].mean()
median = df[col].median()
std = df[col].std()
plus_one_std = mean + std
minus_one_std = mean - std

# %% [markdown]
# ## Graph

# %%
fig,ax=plt.subplots(figsize=(10,6))
sns.histplot(x=df[col], kde=True, stat='density')
ax.axvline(mean, color='red', label = f'Mean={mean:,.2f}')
ax.axvline(median, color='green',label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color='k',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color='k', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(minus_one_std, plus_one_std, alpha=.6, color='yellow',zorder=0)
ax.set_title(f'{col} Distribution')
ax.legend();

# %%
from scipy import stats
kurt = stats.kurtosis(df[col], fisher = False)
kurt
# Out:
# 2.9919958083381206

# %% [markdown]
# ## Questions

# %% [markdown]
# - Is it Discrete or Continuous?
#  - Discrete
# - Does it have a skew? If so, which direction (+/-)
#  - No
# - What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#  - kurt result around 3 so "Mesokurtic"

# %% [markdown]
# # TotalCharge

# %%
#get values
col='TotalCharge'
mean = df[col].mean()
median = df[col].median()
std = df[col].std()
plus_one_std = mean + std
minus_one_std = mean - std

# %% [markdown]
# ## Graph

# %%
fig,ax=plt.subplots(figsize=(10,6))
sns.histplot(x=df[col], kde=True, stat='density')
ax.axvline(mean, color='red', label = f'Mean={mean:,.2f}')
ax.axvline(median, color='green',label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color='k',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color='k', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(minus_one_std, plus_one_std, alpha=.6, color='yellow',zorder=0)
ax.set_title(f'{col} Distribution')
ax.legend();

# %%
from scipy import stats
kurt = stats.kurtosis(df[col], fisher = False)
kurt
# Out:
# 3.2650077463439384

# %% [markdown]
# - Is it Discrete or Continuous?
#  - Continuous
# - Does it have a skew? If so, which direction (+/-)
#  - Yes, to the positive direction
# - What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#  - kurt result greater than 3 so "leptokurtic"
